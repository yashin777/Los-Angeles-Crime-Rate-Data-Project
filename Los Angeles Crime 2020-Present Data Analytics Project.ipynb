# %% [markdown]
# # Los Angeles Crime Rate Data from 2020- Present

# %%
import pandas as pd

# %%
df=pd.read_csv('Crime_Data_from_2020_to_Present.csv')

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0       190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130
# 1       200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2       200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 3       200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037
# 4       220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200
# ...           ...                     ...                     ...       ...
# 982633  242011172  08/20/2024 12:00:00 AM  08/17/2024 12:00:00 AM      2300
# 982634  240710284  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400
# 982635  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
# 982636  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
# 982637  240910892  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300
#
# ...

# %%
df
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0       190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130
# 1       200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2       200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 3       200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037
# 4       220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200
# ...           ...                     ...                     ...       ...
# 982633  242011172  08/20/2024 12:00:00 AM  08/17/2024 12:00:00 AM      2300
# 982634  240710284  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400
# 982635  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
# 982636  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
# 982637  240910892  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300
#
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df.describe()
# Out:
#               DR_NO       TIME OCC           AREA    Rpt Dist No  \
# count  9.826380e+05  982638.000000  982638.000000  982638.000000
# mean   2.197437e+08    1338.945426      10.700277    1116.459887
# std    1.294954e+07     651.537830       6.107808     610.893787
# min    8.170000e+02       1.000000       1.000000     101.000000
# 25%    2.106089e+08     900.000000       5.000000     587.000000
# 50%    2.208146e+08    1420.000000      11.000000    1141.000000
# 75%    2.309153e+08    1900.000000      16.000000    1617.000000
# max    2.499253e+08    2359.000000      21.000000    2199.000000
#
#             Part 1-2         Crm Cd       Vict Age      Premis Cd  \
# count  982638.000000  982638.000000  982638.000000  982624.000000
# mean        1.404253     500.823555      29.079817     306.133008
# std         0.490747     206.211940      21.970094     219.053795
# min         1.000000     110.000000      -4.000000     101.000000
# ...

# %% [markdown]
# # Checking for Missing Values

# %%
df.isnull()
# Out:
#         DR_NO  Date Rptd  DATE OCC  TIME OCC   AREA  AREA NAME  Rpt Dist No  \
# 0       False      False     False     False  False      False        False
# 1       False      False     False     False  False      False        False
# 2       False      False     False     False  False      False        False
# 3       False      False     False     False  False      False        False
# 4       False      False     False     False  False      False        False
# ...       ...        ...       ...       ...    ...        ...          ...
# 982633  False      False     False     False  False      False        False
# 982634  False      False     False     False  False      False        False
# 982635  False      False     False     False  False      False        False
# 982636  False      False     False     False  False      False        False
# 982637  False      False     False     False  False      False        False
#
# ...

# %%
df.isnull().sum()
# Out:
# DR_NO                  0
# Date Rptd              0
# DATE OCC               0
# TIME OCC               0
# AREA                   0
# AREA NAME              0
# Rpt Dist No            0
# Part 1-2               0
# Crm Cd                 0
# Crm Cd Desc            0
# Mocodes           145262
# Vict Age               0
# Vict Sex          138445
# Vict Descent      138456
# Premis Cd             14
# Premis Desc          585
# Weapon Used Cd    656471
# Weapon Desc       656471
# Status                 1
# Status Desc            0
# Crm Cd 1              11
# Crm Cd 2          913763
# Crm Cd 3          980327
# Crm Cd 4          982574
# LOCATION               0
# Cross Street      830789
# LAT                    0
# LON                    0
# dtype: int64

# %% [markdown]
# # Replacing NaN values with 0

# %%
df.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# DR_NO             0
# Date Rptd         0
# DATE OCC          0
# TIME OCC          0
# AREA              0
# AREA NAME         0
# Rpt Dist No       0
# Part 1-2          0
# Crm Cd            0
# Crm Cd Desc       0
# Mocodes           0
# Vict Age          0
# Vict Sex          0
# Vict Descent      0
# Premis Cd         0
# Premis Desc       0
# Weapon Used Cd    0
# Weapon Desc       0
# Status            0
# Status Desc       0
# Crm Cd 1          0
# Crm Cd 2          0
# Crm Cd 3          0
# Crm Cd 4          0
# LOCATION          0
# Cross Street      0
# LAT               0
# LON               0
# dtype: int64

# %%
df
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0       190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130
# 1       200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2       200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 3       200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037
# 4       220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200
# ...           ...                     ...                     ...       ...
# 982633  242011172  08/20/2024 12:00:00 AM  08/17/2024 12:00:00 AM      2300
# 982634  240710284  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400
# 982635  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
# 982636  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
# 982637  240910892  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300
#
# ...

# %% [markdown]
# # Street Locations

# %%
df['LOCATION'].mode()
# 800 N  ALAMEDA has the highest crime location
# Out:
# 0    800 N  ALAMEDA                      ST
# Name: LOCATION, dtype: object

# %%
# Analyzing Location streets in Los Angeles with the highest crime reported
result3=df['LOCATION'].value_counts()
result3
# Out:
# LOCATION
# 800 N  ALAMEDA                      ST      2522
# 700 S  FIGUEROA                     ST      1619
# 10200    SANTA MONICA                 BL    1602
# 100    THE GROVE                    DR      1591
# 6TH                          ST             1572
#                                             ...
# 15800    ROMAR                        ST       1
# 8800    SPARTON                      AV        1
# 01800 W  MICHAEL                      LN       1
# 10700    MOUNT GLEASON                         1
# 12200    ART                          ST       1
# Name: count, Length: 66265, dtype: int64

# %%
# retrieving top 5 Location streets in Los Angeles with the highest crime reported
result4=result3.head(5)
result4
# Out:
# LOCATION
# 800 N  ALAMEDA                      ST      2522
# 700 S  FIGUEROA                     ST      1619
# 10200    SANTA MONICA                 BL    1602
# 100    THE GROVE                    DR      1591
# 6TH                          ST             1572
# Name: count, dtype: int64

# %%
result4.to_csv('result4.csv')

# %%
# Finding the most  Gender Victims occurence
df['Vict Sex'].mode()
# Out:
# 0    M
# Name: Vict Sex, dtype: object

# %%
# Finding the average age of Victims
df['Vict Age'].mean()
# Out:
# 29.079816778915532

# %%
#Finding the Most Area Name reported
df['AREA NAME'].mode()
# Out:
# 0    Central
# Name: AREA NAME, dtype: object

# %%
# Creating a new Dataframe called Crime_result
Crime_result=df.loc[:,['AREA NAME','Crm Cd Desc','DATE OCC','Premis Desc','Vict Age','Vict Sex','LOCATION','Date Rptd']]
Crime_result
# Out:
#         AREA NAME                                        Crm Cd Desc  \
# 0        Wilshire                                   VEHICLE - STOLEN
# 1         Central                              BURGLARY FROM VEHICLE
# 2       Southwest                                      BIKE - STOLEN
# 3        Van Nuys           SHOPLIFTING-GRAND THEFT ($950.01 & OVER)
# 4       Hollywood                                  THEFT OF IDENTITY
# ...           ...                                                ...
# 982633    Olympic  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 982634   Wilshire                                   VEHICLE - STOLEN
# 982635    Central           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 982636  Southwest     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 982637   Van Nuys                                   VEHICLE - STOLEN
#
#                       DATE OCC                                   Premis Desc  \
# ...

# %%
# Creating DataFrame for the Area Name Centeral
Central=Crime_result.loc[Crime_result['AREA NAME']=='Central']
Central
# Out:
#        AREA NAME                                        Crm Cd Desc  \
# 1        Central                              BURGLARY FROM VEHICLE
# 6        Central                                  THEFT OF IDENTITY
# 58       Central                                  THEFT OF IDENTITY
# 60       Central  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 117      Central              INTIMATE PARTNER - AGGRAVATED ASSAULT
# ...          ...                                                ...
# 982552   Central         EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)
# 982573   Central                              BURGLARY FROM VEHICLE
# 982597   Central                           BATTERY - SIMPLE ASSAULT
# 982615   Central                                   VEHICLE - STOLEN
# 982635   Central           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
#
#                       DATE OCC                                   Premis Desc  \
# ...

# %%
Central.to_csv('Central.csv')

# %% [markdown]
# # AREA NAMES

# %%
result=Crime_result['AREA NAME'].value_counts()
result
# Out:
# AREA NAME
# Central        67774
# 77th Street    60865
# Pacific        57810
# Southwest      55978
# Hollywood      51324
# N Hollywood    49978
# Southeast      49119
# Olympic        49023
# Newton         48268
# Wilshire       47090
# Rampart        45818
# West LA        44673
# Northeast      41897
# Van Nuys       41888
# West Valley    41319
# Devonshire     40840
# Harbor         40466
# Topanga        40430
# Mission        39404
# Hollenbeck     36119
# Foothill       32555
# Name: count, dtype: int64

# %%
result.to_csv('result.csv')

# %% [markdown]
# # Crime Descriptions

# %%
result2=Crime_result['Crm Cd Desc'].value_counts()
result2
# Out:
# Crm Cd Desc
# VEHICLE - STOLEN                                           110804
# BATTERY - SIMPLE ASSAULT                                    74688
# BURGLARY FROM VEHICLE                                       61324
# THEFT OF IDENTITY                                           60867
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)     59639
#                                                             ...
# FIREARMS EMERGENCY PROTECTIVE ORDER (FIREARMS EPO)              5
# FIREARMS RESTRAINING ORDER (FIREARMS RO)                        4
# DISHONEST EMPLOYEE ATTEMPTED THEFT                              4
# TRAIN WRECKING                                                  1
# DRUNK ROLL - ATTEMPT                                            1
# Name: count, Length: 140, dtype: int64

# %%
result2.to_csv('result2.csv')

# %%
# Highest Crime_result reported
high_result=Crime_result['Crm Cd Desc'].mode()
high_result
# Out:
# 0    VEHICLE - STOLEN
# Name: Crm Cd Desc, dtype: object

# %%
Crime_result['Crm Cd Desc'].count()
# Out:
# 982638

# %% [markdown]
# # Gender of Victims

# %%
result5=Crime_result['Vict Sex'].value_counts()
result5
# Out:
# Vict Sex
# M    396769
# F    352750
# 0    138445
# X     94561
# H       112
# -         1
# Name: count, dtype: int64

# %%
result5.to_csv('result5.csv')

# %%
Crime_result.to_csv('Crime_result.csv')

# %%
Crime_result['AREA NAME'].mode()
# Out:
# 0    Central
# Name: AREA NAME, dtype: object

# %%
Crime_result['Date Rptd'].value_counts()
# Out:
# Date Rptd
# 02/02/2023 12:00:00 AM    929
# 02/03/2023 12:00:00 AM    927
# 01/03/2023 12:00:00 AM    913
# 05/02/2022 12:00:00 AM    909
# 04/04/2022 12:00:00 AM    883
#                          ...
# 05/26/2024 12:00:00 AM    201
# 07/04/2024 12:00:00 AM    193
# 09/29/2024 12:00:00 AM    188
# 08/11/2024 12:00:00 AM    184
# 07/20/2024 12:00:00 AM    177
# Name: count, Length: 1735, dtype: int64

# %%
Crime_result['Date Rptd'] = pd.to_datetime(Crime_result['Date Rptd'])
# Out:
# /var/folders/qh/b_qb63453x388yxj4q6qfpqm0000gn/T/ipykernel_11661/445261006.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Crime_result['Date Rptd'] = pd.to_datetime(Crime_result['Date Rptd'])

# %%
Crime_result['Date Rptd'] = Crime_result['Date Rptd'].dt.date

# %%
Crime_result['Date Rptd']
# Out:
# 0         2020-03-01
# 1         2020-02-09
# 2         2020-11-11
# 3         2023-05-10
# 4         2022-08-18
#              ...
# 982633    2024-08-20
# 982634    2024-07-24
# 982635    2024-01-15
# 982636    2024-04-24
# 982637    2024-08-13
# Name: Date Rptd, Length: 982638, dtype: object

# %%
Crime_result['Date Rptd'].value_counts()
# Out:
# Date Rptd
# 2023-02-02    929
# 2023-02-03    927
# 2023-01-03    913
# 2022-05-02    909
# 2022-04-04    883
#              ...
# 2024-05-26    201
# 2024-07-04    193
# 2024-09-29    188
# 2024-08-11    184
# 2024-07-20    177
# Name: count, Length: 1735, dtype: int64
