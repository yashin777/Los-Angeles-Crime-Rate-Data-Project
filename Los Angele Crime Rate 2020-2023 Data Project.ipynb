# %% [markdown]
# ## Crime in Los Angeles from 2020-2023

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Crime in LA 2020-present.csv')

# %%
df
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230
# 1       190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330
# 2       200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200
# 3       191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730
# 4       191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415
# ...           ...                     ...                     ...       ...
# 757136  231604807  01/27/2023 12:00:00 AM  01/26/2023 12:00:00 AM      1800
# 757137  231606525  03/22/2023 12:00:00 AM  03/22/2023 12:00:00 AM      1000
# 757138  231210064  04/12/2023 12:00:00 AM  04/12/2023 12:00:00 AM      1630
# 757139  230115220  07/02/2023 12:00:00 AM  07/01/2023 12:00:00 AM         1
# 757140  230906458  03/05/2023 12:00:00 AM  03/05/2023 12:00:00 AM       900
#
# ...

# %%
df.describe()
# Out:
#               DR_NO       TIME OCC           AREA    Rpt Dist No  \
# count  7.571410e+05  757141.000000  757141.000000  757141.000000
# mean   2.148771e+08    1334.814871      10.718368    1118.245674
# std    1.033130e+07     653.847053       6.092302     609.235556
# min    8.170000e+02       1.000000       1.000000     101.000000
# 25%    2.021135e+08     900.000000       6.000000     622.000000
# 50%    2.119136e+08    1415.000000      11.000000    1142.000000
# 75%    2.215089e+08    1900.000000      16.000000    1618.000000
# max    2.399165e+08    2359.000000      21.000000    2199.000000
#
#             Part 1-2         Crm Cd       Vict Age      Premis Cd  \
# count  757141.000000  757141.000000  757141.000000  757132.000000
# mean        1.415613     500.847668      29.909412     305.938960
# std         0.492828     207.952490      21.731307     216.793004
# min         1.000000     110.000000      -2.000000     101.000000
# ...

# %% [markdown]
# The Average Victims age from 2020-2023 were 29 years old.

# %% [markdown]
# # Filling NaN values with the value 0

# %%
df.fillna(0,inplace=True)

# %%
df
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230
# 1       190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330
# 2       200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200
# 3       191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730
# 4       191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415
# ...           ...                     ...                     ...       ...
# 757136  231604807  01/27/2023 12:00:00 AM  01/26/2023 12:00:00 AM      1800
# 757137  231606525  03/22/2023 12:00:00 AM  03/22/2023 12:00:00 AM      1000
# 757138  231210064  04/12/2023 12:00:00 AM  04/12/2023 12:00:00 AM      1630
# 757139  230115220  07/02/2023 12:00:00 AM  07/01/2023 12:00:00 AM         1
# 757140  230906458  03/05/2023 12:00:00 AM  03/05/2023 12:00:00 AM       900
#
# ...

# %% [markdown]
# # Los Angeles AREA NAME

# %%
df['AREA NAME'].unique()
# Out:
# array(['Southwest', 'Central', 'N Hollywood', 'Mission', 'Devonshire',
#        'Northeast', 'Harbor', 'Van Nuys', 'West Valley', 'West LA',
#        'Wilshire', 'Pacific', 'Rampart', '77th Street', 'Hollenbeck',
#        'Southeast', 'Hollywood', 'Newton', 'Topanga', 'Foothill',
#        'Olympic'], dtype=object)

# %%
df['AREA NAME'].mode()
# Out:
# 0    Central
# dtype: object

# %% [markdown]
#  There are 21 areas in Los Angeles listed above.  The Highest Crime Area in Los Angeles is Central.

# %% [markdown]
# # Gender Victims

# %%
df['Vict Sex'].unique()
# Out:
# array(['F', 'M', 'X', 0, 'H', '-'], dtype=object)

# %%
df['Vict Sex'].mode()
# Out:
# 0    M
# dtype: object

# %% [markdown]
# The gender that were victimize the most were male
